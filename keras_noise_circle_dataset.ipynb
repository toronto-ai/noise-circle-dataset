# %% [markdown]
# Work in progress:
# - add tensorboard support (see https://stackoverflow.com/questions/47818822/can-i-use-tensorboard-with-google-colab)
# - model save / restore
# - retrain / fine-tune network based on pretrained weights

# %% [markdown]
# ![Toronto AI](https://i.imgur.com/diILtDP.png)

# %% [markdown]
# # Neural Networks
#
# A trained neural net can be thought of as a learned mapping.
#
# Here are some examples of mappings that a neural net could learn:
#
# *   Mapping English to French
# *   Mapping pictures to text descriptions
# *   Mapping live sensor data from a reusable rocket to control commands that land it
# *   Mapping random vectors into images of flowers
#
# In essence, we use neural nets to map one distribution of data onto another.
#
# Here's an an example where I trained a neural net to map random vectors onto the space of flower photos, using a Generative Adversarial Network:
#
# ![](https://i.imgur.com/SaT9OEM.png)

# %% [markdown]
# # Tensors
#
# * Tensors are multidimensional arrays.
# * They are like boxes of data, that we use to contain our data, or the weights of our model.
# * Tensors are used extensively in TensorFlow to represent:
#   * 0-D - scalars
#   * 1-D - vectors, text
#   * 2-D - matrices, tables of data
#   * 3-D - batches of matrices, a cube of data, e.g. an image, a monochrome video
#   * 4-D - convolution kernels, a colour video
#   * 5-D - batches of colour video
#   * 6-D - 3D vector fields
#   * 7-D - layered 3D vector fields (e.g. gravity and electromagnetism layers)
#   * 8-D - batches of layered 3D vector fields
#   * 9-D - batches of layered 3D vector fields evolving through time
#   * keep going...
#
# * GPU memory is expensive, so Tensors are most commonly 4-D or less.
#
# * It helps to visualize a Tensor as a Rubiks Cube - each cell holds a piece of scalar data (like a weight, a piece of input data, or a label).  For higher dimensional Tensors, think of each cell as holding a Tensor instead of a scalar.
# ![](https://i.imgur.com/KyOQVX9.png)

# %% [markdown]
# This notebook is based on Toronto AI - Noise-Circle Synthetic Dataset https://github.com/toronto-ai/noise-circle-dataset, modified for Google Colab environment using Keras.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2330196015497461093, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11297803469
#  locality {
#    bus_id: 1
#  }
#  incarnation: 5422562790259915404
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %% [markdown]
# Mapping your Google Drive space to Colab

# %%
# todo

# use mapped google drive url instead
#import os
#DIRECTORY = os.path.join("~", "ai")

# %%
# https://keras.io/
# !pip install -q keras

from __future__ import print_function
import keras
from keras.models import Sequential
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Flatten, Lambda
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.losses import mean_squared_error
from keras.optimizers import  Adam
from keras.callbacks import Callback
from keras import backend as K

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random, math
from matplotlib import animation, rc
from IPython.display import HTML

# %%
plt.rcParams['image.cmap'] = 'viridis'

np.random.seed(20180118)

BATCH_SIZE = 16
DIM = 64
TWO_PI = 2.*math.pi
MIN_CIRCLE_WIDTH = int(DIM/10)
NUM_CIRCLE_DOTS = 500
CIRCLE_WIDTH = 3
DARKNESS = .5

# %%
# We'll use this to create our data set.
def add_circles(data):
    radius = int((random.random() * (DIM/2 - MIN_CIRCLE_WIDTH)) + MIN_CIRCLE_WIDTH)
    xpos = random.random()*DIM
    ypos = random.random()*DIM
    
    draw_circle(data, xpos, ypos, radius, DARKNESS, CIRCLE_WIDTH)

    return [xpos, ypos, radius+CIRCLE_WIDTH/2]


def draw_circle(data, xpos, ypos, radius, darkness, width):
    for i in range(NUM_CIRCLE_DOTS):
        for r in range(radius, radius+width):
            rad = TWO_PI * i/NUM_CIRCLE_DOTS
            x = int(round(r*math.cos(rad)+xpos))
            y = int(round(-r*math.sin(rad)+ypos))
            if x >= 0 and x < DIM and y >= 0 and y < DIM:
                data[x,y] = data[x,y] - darkness

# Create random noise and draw circles in it
def create_dataset_row():
    data = np.random.random((DIM, DIM)).astype(np.float32)
    label = add_circles(data)
    label = np.array(label).astype(np.float32)
    
    return (data, label)
    

def create_dataset(rows):
    
    labels  = []
    samples = []
    for i in range(rows):
        data, label = create_dataset_row()
        labels.append(label)
        samples.append(data)
    return (np.array(samples).astype(np.float32), np.array(labels).astype(np.float32))

def plot_dataset(data):
    fig, ax = plt.subplots()

    def init():
        ax.cla()
        return ()

    def animate(i):
        ax.imshow(data[i%len(data)])
        return ()

    anim = animation.FuncAnimation(fig, animate, init_func=init, frames=BATCH_SIZE, interval=700, blit=True)
    plt.close(fig)
    fig.set_size_inches(10, 10, True)
    return HTML(anim.to_jshtml())

# %%
# Create an animation so we can see our data set
dataset = create_dataset(BATCH_SIZE)
data   = dataset[0]
labels = dataset[1]

plot_dataset(data)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge53f9064fb8f4c9f9df75730c5dfbd7e">
#     <br>
#     <input id="_anim_slidere53f9064fb8f4c9f9df75730c5dfbd7e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime53f9064fb8f4c9f9df75730c5dfbd7e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime53f9064fb8f4c9f9df75730c5dfbd7e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte53f9064fb8f4c9f9df75730c5dfbd7e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge53f9064fb8f4c9f9df75730c5dfbd7e";
#     var slider_id = "_anim_slidere53f9064fb8f4c9f9df75730c5dfbd7e";
#     var loop_select_id = "_anim_loop_selecte53f9064fb8f4c9f9df75730c5dfbd7e";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAIABJREFUeJzs3Wd8VWXW9/GV3jvpgYQAoYuigKCA\
# KCgwFkBRZOyODqMzI2MfB8V228VRR8eOChaKBQsKdkUBAQXpPSGk996T58V8Pic5ObhWtuAtcz+/\
# 76vsax3/npyyc7GTs5ZXW1tbmwAAAADoEu/f+g4AAAAA/03YQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwgA00AAAA4AAbaAAAAMABNtAAAACAA2ygAQAAAAfYQAMAAAAOsIEGAAAAHGADDQAAADjA\
# BhoAAABwwPe3vgMQGbHiVrfj10fNlpnf/dN17OPVZma81H+BWl9Tl2pmpPkXq/X3y48zM34qS1br\
# ZyZsNjPOCN2m1p8uHmtmzIn7yu04Ou5zKS081XW8vMZ+PEK8G9X6M9n2/bg4ebVafy5zjJlxV59l\
# an1VdV8zY0N5D7XuLfZrbEjkQbfjP/d5XP61+zrX8XHBWWbGzvpEtb6hQr+fIiLDIjPV+qkh282M\
# Y/x91PoXdYFmxjO5p6j1AeH5ZkZpU4jb8e0D7pd7tv3ddTwlaoOZsaJisFofHb7LzGhs0x+P80Mr\
# zIx5pelqvaAp3MxoaNV/JA0IzjUzVhYPcDv+57G3y+yN97iOU4NLzYxPsvX3VPO6KDMjuFB/T8Ut\
# 0c9zIiJ5Fw1U6wFlrWZGZbp+nazbyXlmRq8I958N/zPobvnHljtcx9tL482MgdH6+yHEt8HMGBG2\
# T60HejWZGS/mnKzWj+10njuU8yPXqfWNDd3NjO11SW7HN2Q8Ko/uusF1/LuIjWbGnN1T1Xqov/2Y\
# fjz2cfM2ODQ20L+S++67TzZt2iReXl5y2223yTHHHNPl/7ZXWMKveM/+/+Tr1++3vgv/58QH2v8I\
# gTPJQSm/9V34P6dHSJJ9IziSEszr9EhLCLIvHuDowgb6V/D9999LVlaWLFq0SPbu3Su33XabLFq0\
# 6Le+WwAAADgC+BvoX8Hq1atl/PjxIiLSq1cvqaiokOrq6t/4XgEAAOBIYAP9KyguLpaoqPa/kYuO\
# jpaioqLf8B4BAADgSPFqa2uzPz0ER26//XYZO3as6yr0hRdeKPfdd5/07NnzkLffW5XP3z0DAAD8\
# l+BvoH8FcXFxUlzc/qnlwsJCiY2N/dnbd+y4ISKy9owH3Dpz0IXD3S/pwhGXnCuFO

# %% [markdown]
# Build the Keras Model here
#
# input: BATCH_SIZE x 64 x 64 x 1
#
# TRUNK:
# C1 - CONV: 32 filters, 7x7 kernal, relu
# C2 - CONV: 32 filters, 7x7 kernal, relu
# C3 - CONV: 32 filters, 7x7 kernal, relu
#
# C4 - CONV: 32 filters, 7x7 kernal, relu
# A4 - AVG POOLING: 2x2, strides 2
#
# C5 - CONV: 32 filters, 7x7 kernal, relu
# A5 - AVG POOLING: 2x2, strides 2
#
# C6 - CONV: 32 filters, 7x7 kernal, relu
# A6 - AVG POOLING: 2x2, strides 2
#
# output': BATCH_SIZE x 8 x 8 x 32
#
# HEAD (3x, one for xpos, one for ypos and one for radius)
#
# D7x - DENSE: 32, elu
# D8x - DENSE: 32, elu
# D9x - DENSE: 32, elu
#
# output: sum(D7x,D8x,D9x)

# %%
# Setup the input to the network

# check the CPU/GPU image convention
# based on keras mnist example
if K.image_data_format() == 'channels_first':
    input_shape = (1, DIM, DIM)
else:
    input_shape = (DIM, DIM, 1)
    
#main_input = Input(shape=input_shape, dtype='float32', name='main_input')

# Batch version
main_input = Input(batch_shape=(BATCH_SIZE,)+input_shape, dtype='float32', name='main_input')

# %%
# number of filters per conv2d layers
FS = 32

# conv2d kernel window size
KerSz  = 7

#Ref:
# keras.layers.Conv2D(filters, kernel_size, strides=(1, 1), padding='valid', 
#   data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True, 
#   kernel_initializer='glorot_uniform', bias_initializer='zeros', 
#   kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, 
#   kernel_constraint=None, bias_constraint=None)
conv = Conv2D(FS, (KerSz, KerSz), padding='same',activation='relu',kernel_initializer='glorot_normal')

# keras.layers.AveragePooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None)
avgp = AveragePooling2D(pool_size=(2, 2), strides=(2,2))
maxp = MaxPooling2D(pool_size=(2, 2), strides=(2,2))

# %%
# C1
# without the input_shape at first conv2d it won't work!
x = Conv2D(FS, (KerSz, KerSz), padding='same',activation='relu', 
           input_shape=input_shape)(main_input)

x = conv(x) # C2
x = conv(x) # C3

x = conv(x) # C4
x = avgp(x) # A4 (swap out with maxp if you want)

x = conv(x) # C5
x = avgp(x) # A5 (swap out with maxp if you want)

x = conv(x) # C6
x = avgp(x) # A6 (swap out with maxp if you want)

# flattern the conv2d layer output to make it a table, one row for each example 
# in the batch.
xf = Flatten()(x)

# %%
# make lambda layers between the trunk and head
# https://keras.io/layers/core/
# stackoverflow: https://github.com/keras-team/keras/issues/890
# keras.layers.Lambda(function, output_shape=None, mask=None, arguments=None)
#
# split the conv2d layer output for x,y,r estimation branches

#a_third  = int(x.shape[1].value / 3)
a_third = 682 # hard coded (TODO: fix this!!!)

xx = Lambda(lambda x: x[:,0*a_third:(0+1)*a_third])(xf)
yy = Lambda(lambda x: x[:,1*a_third:(1+1)*a_third])(xf)
rr = Lambda(lambda x: x[:,2*a_third:(2+1)*a_third])(xf)

# %%
# feed the input to the sub networks for regression (e.g.x_guess, y_guess etc.)

# number of neurons in the hidden layers
DS = 32 
af = 'elu'

# Reference:
# keras.layers.Dense(units, activation=None, use_bias=True, 
#   kernel_initializer='glorot_uniform', bias_initializer='zeros', 
#   kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, 
#   kernel_constraint=None, bias_constraint=None)

def denseSubnet(name,input):
  layer = Dense(DS,activation=af,kernel_initializer='glorot_normal')(input)
  layer = Dense(DS,activation=af,kernel_initializer='glorot_normal')(layer)
  layer = Dense(DS,activation=af,kernel_initializer='glorot_normal')(layer)
  # instead of using sum (which doesn't work here)
  #   return Lambda(lambda x: K.sum(x, axis=1))(layer)
  layer = Dense(1,activation='linear',name=name)(layer) 
  return layer

x_guess = denseSubnet('x_guess',xx)
y_guess = denseSubnet('y_guess',yy)
r_guess = denseSubnet('r_guess',rr)

# try without spliting up the conv2d output later
#x_guess = denseSubnet('x_guess',xf)
#y_guess = denseSubnet('y_guess',xf)
#r_guess = denseSubnet('r_guess',xf)

# %%
model = Model(inputs=[main_input], outputs=[x_guess,y_guess,r_guess])

# display the model
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (16, 64, 64, 1)      0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (16, 64, 64, 32)     1600        main_input[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               multiple             50208       conv2d_2[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_1[1][0]
#                                                                  average_pooling2d_1[0][0]
#                                                                  average_pooling2d_1[1][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo multiple             0           conv2d_1[2][0]
#                                                                  conv2d_1[3][0]
#                                                                  conv2d_1[4][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (16, 2048)           0           average_pooling2d_1[2][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (16, 682)            0           flatten_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (16, 682)            0           flatten_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (16, 682)            0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (16, 32)             21856       lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (16, 32)             21856       lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (16, 32)             21856       lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (16, 32)             1056        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (16, 32)             1056        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (16, 32)             1056        dense_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (16, 32)             1056        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (16, 32)             1056        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (16, 32)             1056        dense_8[0][0]
# __________________________________________________________________________________________________
# x_guess (Dense)                 (16, 1)              33          dense_3[0][0]
# __________________________________________________________________________________________________
# y_guess (Dense)                 (16, 1)              33          dense_6[0][0]
# __________________________________________________________________________________________________
# r_guess (Dense)                 (16, 1)              33          dense_9[0][0]
# ==================================================================================================
# Total params: 123,811
# Trainable params: 123,811
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Define the custom loss and metric for the network, required for the model.fit in Keras
#
# TODO: The metric and loss output doesn't make sense

# %%
# Ref:
# https://github.com/keras-team/keras/blob/master/keras/losses.py
def loss_metric_helper(y_true, y_pred):
  actual_x, actual_y, actual_r = y_true[0], y_true[1], y_true[2]
  x,y,r = y_pred[0], y_pred[1], y_pred[2]
  
  # Define an error between the predicted x, y and radius, and their actual values
  # We will later ask the network to minimize this error through gradient descent
  err = mean_squared_error(y_true, y_pred)
  x_error, y_error, r_error = err[0],err[1],err[2]
  
  return x_error, y_error, r_error

def loss_function(y_true, y_pred):
  x_error, y_error, r_error = loss_metric_helper(y_true, y_pred)
  
  # Let's combine these individual loss metrics into a combined loss function
  # Note: these are vectors - with separate losses defined for each element in the batch 
  return x_error + y_error + r_error

def avg_dist_metric(y_true, y_pred):
  x_error, y_error, _ = loss_metric_helper(y_true, y_pred)
    
  # Now lets create some metrics that we can use to evaluate our progress
  avg_distance_from_actual_center = x_error + y_error
  return avg_distance_from_actual_center

def avg_radius_error_metric(y_true, y_pred):
  _, _, r_error = loss_metric_helper(y_true, y_pred)
  avg_radius_error = r_error
  return avg_radius_error

# %%
# setup the optimizer
# ref: https://keras.io/optimizers/
# keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False

ALPHA = 0.001
BETA1 = 0.9
BETA2 = 0.999
EPSILON=None #1e-9

opt = Adam(lr=ALPHA,beta_1=BETA1,beta_2=BETA2,epsilon=EPSILON)

# %%
# try to compile the model
model.compile(loss=loss_function, 
              optimizer=opt,
              metrics=[avg_dist_metric, avg_radius_error_metric])

# %% [markdown]
# Define the batch sample generator to generate an infinite dataset in Keras convention
#
# Ref:
# https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.html

# %%
class DataGenerator(object):
  def __init__(self, dim_x = 32, dim_y = 32, dim_z = 32, batch_size = 32, shuffle = True):
    'Initialization'
    self.dim_x = dim_x
    self.dim_y = dim_y
    self.batch_size = batch_size
    self.shuffle = shuffle
    
  def generate(self):
    'Generates batches of samples'
    # Infinite loop
    while 1:
      # Generate order of exploration of dataset
      samples = np.zeros((BATCH_SIZE,DIM,DIM,1))
      ds = create_dataset(BATCH_SIZE)
      samples[:,:,:,0] = ds[0]
      labels = ds[1]
      yield (samples,[labels[:,0],labels[:,1],labels[:,2]])

  def generateOne(self):
    # one sample batch output
    samples = np.zeros((BATCH_SIZE,DIM,DIM,1))
    ds = create_dataset(BATCH_SIZE)
    samples[:,:,:,0] = ds[0]
    labels = ds[1]
    return (samples,[labels[:,0],labels[:,1],labels[:,2]])
      
# Parameters
params = {'dim_x': DIM,
          'dim_y': DIM,
          'batch_size': BATCH_SIZE,
          'shuffle': False}

generator = DataGenerator(**params).generate()

# %% [markdown]
# Define callbacks for misc. purpose

# %%
# Ref:
# https://keras.io/callbacks/#example-recording-loss-history
class LossHistory(keras.callbacks.Callback):
  def __init__(self):
    self.idx = 0
    
  def on_train_begin(self, logs={}):
    self.losses = []

  def on_batch_end(self, batch, logs={}):
    #self.losses.append(logs.get('metric'))  
    xErr = logs.get('x_guess_avg_dist_metric')
    yErr = logs.get('y_guess_avg_dist_metric')
    rErr = logs.get('r_guess_avg_radius_error_metric')
    
    ema_radius = rErr
    ema_center = (xErr + yErr)/2

    print("step: {step}, \
      EMA radius error: {ema_radius:.0f}px. \
      EMA center error: {ema_center:.0f}px".format(step=self.idx, 
                                                   ema_radius=ema_radius, 
                                                   ema_center=ema_center))
    self.idx += 1
  
history = LossHistory()

# %% [markdown]
# train the model with generator

# %%
np.random.seed(20180118)
model.fit_generator(generator = generator,
                    steps_per_epoch=1, epochs=1000,
                    workers = 0 , # This is important
                    verbose = 0,
                    callbacks=[history])
# Out:
# step: 0,       EMA radius error: 0px.       EMA center error: 36px
# step: 1,       EMA radius error: 0px.       EMA center error: 36px
# step: 2,       EMA radius error: 5px.       EMA center error: 34px
# step: 3,       EMA radius error: 3px.       EMA center error: 100px
# step: 4,       EMA radius error: 0px.       EMA center error: 33px
# step: 5,       EMA radius error: 5px.       EMA center error: 14px
# step: 6,       EMA radius error: 9px.       EMA center error: 9px
# step: 7,       EMA radius error: 28px.       EMA center error: 59px
# step: 8,       EMA radius error: 10px.       EMA center error: 24px
# step: 9,       EMA radius error: 0px.       EMA center error: 38px
# step: 10,       EMA radius error: 4px.       EMA center error: 26px
# step: 11,       EMA radius error: 0px.       EMA center error: 13px
# step: 12,       EMA radius error: 0px.       EMA center error: 4px
# step: 13,       EMA radius error: 11px.       EMA center error: 13px
# step: 14,       EMA radius error: 1px.       EMA center error: 14px
# step: 15,       EMA radius error: 44px.       EMA center error: 6px
# step: 16,       EMA radius error: 30px.       EMA center error: 22px
# step: 17,       EMA radius error: 0px.       EMA center error: 25px
# step: 18,       EMA radius error: 0px.       EMA center error: 25px
# step: 19,       EMA radius error: 9px.       EMA center error: 16px
# step: 20,       EMA radius error: 1px.       EMA center error: 7px
# step: 21,       EMA radius error: 1px.       EMA center error: 25px
# step: 22,       EMA radius error: 1px.       EMA center error: 25px
# step: 23,       EMA radius error: 23px.       EMA center error: 18px
# step: 24,       EMA radius error: 1px.       EMA center error: 18px
# step: 25,       EMA radius error: 7px.       EMA center error: 15px
# step: 26,       EMA radius error: 0px.       EMA center error: 475px
# step: 27,       EMA radius error: 0px.       EMA center error: 71px
# step: 28,       EMA radius error: 0px.       EMA center error: 16px
# step: 29,       EMA radius error: 3px.       EMA center error: 19px
# step: 30,       EMA radius error: 2px.       EMA center error: 15px
# step: 31,       EMA radius error: 22px.       EMA center error: 28px
# step: 32,       EMA radius error: 10px.       EMA center error: 12px
# step: 33,       EMA radius error: 7px.       EMA center error: 22px
# step: 34,       EMA radius error: 0px.       EMA center error: 25px
# step: 35,       EMA radius error: 1px.       EMA center error: 11px
# step: 36,       EMA radius error: 3px.       EMA center error: 5px
# step: 37,       EMA radius error: 0px.       EMA center error: 13px
# step: 38,       EMA radius error: 0px.       EMA center error: 31px
# step: 39,       EMA radius error: 6px.       EMA center error: 24px
# step: 40,       EMA radius error: 1px.       EMA center error: 18px
# step: 41,       EMA radius error: 4px.       EMA center error: 28px
# step: 42,       EMA radius error: 3px.       EMA center error: 43px
# step: 43,       EMA radius error: 0px.       EMA center error: 5px
# step: 44,       EMA radius error: 1px.       EMA center error: 21px
# step: 45,       EMA radius error: 0px.       EMA center error: 14px
# step: 46,       EMA radius error: 0px.       EMA center error: 9px
# step: 47,       EMA radius error: 3px.       EMA center error: 7px
# step: 48,       EMA radius error: 1px.       EMA center error: 10px
# step: 49,       EMA radius error: 0px.       EMA center error: 5px
# step: 50,       EMA radius error: 0px.       EMA center error: 7px
# step: 51,       EMA radius error: 0px.       EMA center error: 6px
# step: 52,       EMA radius error: 0px.       EMA center error: 2px
# step: 53,       EMA radius error: 1px.       EMA center error: 11px
# step: 54,       EMA radius error: 0px.       EMA center error: 11px
# step: 55,       EMA radius error: 0px.       EMA center error: 7px
# step: 56,       EMA radius error: 4px.       EMA center error: 20px
# step: 57,       EMA radius error: 0px.       EMA center error: 4px
# step: 58,       EMA radius error: 0px.       EMA center error: 10px
# step: 59,       EMA radius error: 0px.       EMA center error: 5px
# step: 60,       EMA radius error: 2px.       EMA center error: 6px
# step: 61,       EMA radius error: 5px.       EMA center error: 24px
# step: 62,       EMA radius error: 1px.       EMA center error: 4px
# step: 63,       EMA radius error: 12px.       EMA center error: 9px
# step: 64,       EMA radius error: 0px.       EMA center error: 6px
# step: 65,       EMA radius error: 0px.       EMA center error: 2px
# step: 66,       EMA radius error: 3px.       EMA center error: 16px
# step: 67,       EMA radius error: 4px.       EMA center error: 3px
# step: 68,       EMA radius error: 1px.       EMA center error: 12px
# step: 69,       EMA radius error: 0px.       EMA center error: 6px
# step: 70,       EMA radius error: 2px.       EMA center error: 3px
# step: 71,       EMA radius error: 2px.       EMA center error: 2px
# step: 72,       EMA radius error: 1px.       EMA center error: 5px
# step: 73,       EMA radius error: 6px.       EMA center error: 4px
# step: 74,       EMA radius error: 1px.       EMA center error: 9px
# step: 75,       EMA radius error: 0px.       EMA center error: 3px
# step: 76,       EMA radius error: 1px.       EMA center error: 2px
# step: 77,       EMA radius error: 0px.       EMA center error: 6px
# step: 78,       EMA radius error: 1px.       EMA center error: 1px
# step: 79,       EMA radius error: 2px.       EMA center error: 7px
# step: 80,       EMA radius error: 2px.       EMA center error: 5px
# step: 81,       EMA radius error: 0px.       EMA center error: 6px
# step: 82,       EMA radius error: 0px.       EMA center error: 4px
# step: 83,       EMA radius error: 1px.       EMA center error: 19px
# step: 84,       EMA radius error: 7px.       EMA center error: 2px
# step: 85,       EMA radius error: 1px.       EMA center error: 0px
# step: 86,       EMA radius error: 0px.       EMA center error: 6px
# step: 87,       EMA radius error: 1px.       EMA center error: 1px
# step: 88,       EMA radius error: 2px.       EMA center error: 4px
# step: 89,       EMA radius error: 2px.       EMA center error: 13px
# step: 90,       EMA radius error: 0px.       EMA center error: 16px
# step: 91,       EMA radius error: 1px.       EMA center error: 10px
# step: 92,       EMA radius error: 7px.       EMA center error: 2px
# step: 93,       EMA radius error: 1px.       EMA center error: 7px
# step: 94,       EMA radius error: 0px.       EMA center error: 2px
# step: 95,       EMA radius error: 8px.       EMA center error: 7px
# step: 96,       EMA radius error: 1px.       EMA center error: 8px
# step: 97,       EMA radius error: 4px.       EMA center error: 4px
# step: 98,       EMA radius error: 1px.       EMA center error: 9px
# step: 99,       EMA radius error: 32px.       EMA center error: 4px
# step: 100,       EMA radius error: 1px.       EMA center error: 3px
# step: 101,       EMA radius error: 3px.       EMA center error: 7px
# step: 102,       EMA radius error: 1px.       EMA center error: 4px
# step: 103,       EMA radius error: 1px.       EMA center error: 5px
# step: 104,       EMA radius error: 6px.       EMA center error: 1px
# step: 105,       EMA radius error: 3px.       EMA center error: 1px
# step: 106,       EMA radius error: 3px.       EMA center error: 5px
# step: 107,       EMA radius error: 4px.       EMA center error: 1px
# step: 108,       EMA radius error: 3px.       EMA center error: 4px
# step: 109,       EMA radius error: 0px.       EMA center error: 1px
# step: 110,       EMA radius error: 0px.       EMA center error: 0px
# step: 111,       EMA radius error: 4px.       EMA center error: 11px
# step: 112,       EMA radius error: 0px.       EMA center error: 3px
# step: 113,       EMA radius error: 0px.       EMA center error: 3px
# step: 114,       EMA radius error: 4px.       EMA center error: 19px
# step: 115,       EMA radius error: 1px.       EMA center error: 5px
# step: 116,       EMA radius error: 0px.       EMA center error: 10px
# step: 117,       EMA radius error: 5px.       EMA center error: 3px
# step: 118,       EMA radius error: 2px.       EMA center error: 4px
# step: 119,       EMA radius error: 0px.       EMA center error: 9px
# step: 120,       EMA radius error: 0px.       EMA center error: 4px
# step: 121,       EMA radius error: 1px.       EMA center error: 4px
# step: 122,       EMA radius error: 0px.       EMA center error: 2px
# step: 123,       EMA radius error: 0px.       EMA center error: 1px
# step: 124,       EMA radius error: 0px.       EMA center error: 1px
# step: 125,       EMA radius error: 1px.       EMA center error: 0px
# step: 126,       EMA radius error: 1px.       EMA center error: 1px
# step: 127,       EMA radius error: 0px.       EMA center error: 4px
# step: 128,       EMA radius error: 2px.       EMA center error: 7px
# step: 129,       EMA radius error: 1px.       EMA center error: 1px
# step: 130,       EMA radius error: 5px.       EMA center error: 6px
# step: 131,       EMA radius error: 0px.       EMA center error: 5px
# step: 132,       EMA radius error: 1px.       EMA center error: 4px
# step: 133,       EMA radius error: 1px.       EMA center error: 4px
# step: 134,       EMA radius error: 0px.       EMA center error: 1px
# step: 135,       EMA radius error: 0px.       EMA center error: 2px
# step: 136,       EMA radius error: 0px.       EMA center error: 0px
# step: 137,       EMA radius error: 2px.       EMA center error: 2px
# step: 138,       EMA radius error: 1px.       EMA center error: 5px
# step: 139,       EMA radius error: 0px.       EMA center error: 12px
# step: 140,       EMA radius error: 0px.       EMA center error: 1px
# step: 141,       EMA radius error: 2px.       EMA center error: 5px
# step: 142,       EMA radius error: 0px.       EMA center error: 7px
# step: 143,       EMA radius error: 1px.       EMA center error: 8px
# step: 144,       EMA radius error: 20px.       EMA center error: 6px
# step: 145,       EMA radius error: 0px.       EMA center error: 16px
# step: 146,       EMA radius error: 1px.       EMA center error: 1px
# step: 147,       EMA radius error: 9px.       EMA center error: 3px
# step: 148,       EMA radius error: 0px.       EMA center error: 1px
# step: 149,       EMA radius error: 1px.       EMA center error: 5px
# step: 150,       EMA radius error: 1px.       EMA center error: 13px
# step: 151,       EMA radius error: 1px.       EMA center error: 9px
# step: 152,       EMA radius error: 1px.       EMA center error: 5px
# step: 153,       EMA radius error: 0px.       EMA center error: 4px
# step: 154,       EMA radius error: 0px.       EMA center error: 4px
# step: 155,       EMA radius error: 0px.       EMA center error: 3px
# step: 156,       EMA radius error: 0px.       EMA center error: 0px
# step: 157,       EMA radius error: 0px.       EMA center error: 2px
# step: 158,       EMA radius error: 0px.       EMA center error: 5px
# step: 159,       EMA radius error: 1px.       EMA center error: 2px
# step: 160,       EMA radius error: 3px.       EMA center error: 1px
# step: 161,       EMA radius error: 1px.       EMA center error: 3px
# step: 162,       EMA radius error: 5px.       EMA center error: 1px
# step: 163,       EMA radius error: 1px.       EMA center error: 1px
# step: 164,       EMA radius error: 2px.       EMA center error: 8px
# step: 165,       EMA radius error: 0px.       EMA center error: 1px
# step: 166,       EMA radius error: 0px.       EMA center error: 1px
# step: 167,       EMA radius error: 0px.       EMA center error: 3px
# step: 168,       EMA radius error: 0px.       EMA center error: 3px
# step: 169,       EMA radius error: 2px.       EMA center error: 3px
# step: 170,       EMA radius error: 0px.       EMA center error: 8px
# step: 171,       EMA radius error: 1px.       EMA center error: 1px
# step: 172,       EMA radius error: 0px.       EMA center error: 4px
# step: 173,       EMA radius error: 2px.       EMA center error: 2px
# step: 174,       EMA radius error: 1px.       EMA center error: 4px
# step: 175,       EMA radius error: 4px.       EMA center error: 4px
# step: 176,       EMA radius error: 0px.       EMA center error: 2px
# step: 177,       EMA radius error: 0px.       EMA center error: 1px
# step: 178,       EMA radius error: 0px.       EMA center error: 2px
# step: 179,       EMA radius error: 6px.       EMA center error: 1px
# step: 180,       EMA radius error: 0px.       EMA center error: 6px
# step: 181,       EMA radius error: 0px.       EMA center error: 6px
# step: 182,       EMA radius error: 0px.       EMA center error: 3px
# step: 183,       EMA radius error: 0px.       EMA center error: 3px
# step: 184,       EMA radius error: 0px.       EMA center error: 1px
# step: 185,       EMA radius error: 6px.       EMA center error: 1px
# step: 186,       EMA radius error: 0px.       EMA center error: 1px
# step: 187,       EMA radius error: 1px.       EMA center error: 5px
# step: 188,       EMA radius error: 1px.       EMA center error: 3px
# step: 189,       EMA radius error: 0px.       EMA center error: 2px
# step: 190,       EMA radius error: 2px.       EMA center error: 4px
# step: 191,       EMA radius error: 0px.       EMA center error: 1px
# step: 192,       EMA radius error: 0px.       EMA center error: 12px
# step: 193,       EMA radius error: 2px.       EMA center error: 3px
# step: 194,       EMA radius error: 2px.       EMA center error: 1px
# step: 195,       EMA radius error: 1px.       EMA center error: 1px
# step: 196,       EMA radius error: 1px.       EMA center error: 4px
# step: 197,       EMA radius error: 1px.       EMA center error: 5px
# step: 198,       EMA radius error: 0px.       EMA center error: 2px
# step: 199,       EMA radius error: 0px.       EMA center error: 8px
# step: 200,       EMA radius error: 0px.       EMA center error: 5px
# step: 201,       EMA radius error: 4px.       EMA center error: 5px
# step: 202,       EMA radius error: 0px.       EMA center error: 2px
# step: 203,       EMA radius error: 5px.       EMA center error: 2px
# step: 204,       EMA radius error: 0px.       EMA center error: 0px
# step: 205,       EMA radius error: 1px.       EMA center error: 1px
# step: 206,       EMA radius error: 1px.       EMA center error: 2px
# step: 207,       EMA radius error: 0px.       EMA center error: 1px
# step: 208,       EMA radius error: 4px.       EMA center error: 1px
# step: 209,       EMA radius error: 1px.       EMA center error: 2px
# step: 210,       EMA radius error: 0px.       EMA center error: 2px
# step: 211,       EMA radius error: 0px.       EMA center error: 2px
# step: 212,       EMA radius error: 0px.       EMA center error: 4px
# step: 213,       EMA radius error: 0px.       EMA center error: 2px
# step: 214,       EMA radius error: 0px.       EMA center error: 7px
# step: 215,       EMA radius error: 4px.       EMA center error: 2px
# step: 216,       EMA radius error: 4px.       EMA center error: 5px
# step: 217,       EMA radius error: 0px.       EMA center error: 2px
# step: 218,       EMA radius error: 0px.       EMA center error: 5px
# step: 219,       EMA radius error: 2px.       EMA center error: 1px
# step: 220,       EMA radius error: 0px.       EMA center error: 3px
# step: 221,       EMA radius error: 9px.       EMA center error: 7px
# step: 222,       EMA radius error: 2px.       EMA center error: 3px
# step: 223,       EMA radius error: 1px.       EMA center error: 9px
# step: 224,       EMA radius error: 0px.       EMA center error: 2px
# step: 225,       EMA radius error: 0px.       EMA center error: 3px
# step: 226,       EMA radius error: 4px.       EMA center error: 3px
# step: 227,       EMA radius error: 3px.       EMA center error: 4px
# step: 228,       EMA radius error: 0px.       EMA center error: 13px
# step: 229,       EMA radius error: 1px.       EMA center error: 2px
# step: 230,       EMA radius error: 1px.       EMA center error: 0px
# step: 231,       EMA radius error: 1px.       EMA center error: 15px
# step: 232,       EMA radius error: 0px.       EMA center error: 4px
# step: 233,       EMA radius error: 0px.       EMA center error: 2px
# step: 234,       EMA radius error: 1px.       EMA center error: 1px
# step: 235,       EMA radius error: 13px.       EMA center error: 9px
# step: 236,       EMA radius error: 2px.       EMA center error: 4px
# step: 237,       EMA radius error: 0px.       EMA center error: 5px
# step: 238,       EMA radius error: 2px.       EMA center error: 4px
# step: 239,       EMA radius error: 0px.       EMA center error: 5px
# step: 240,       EMA radius error: 3px.       EMA center error: 3px
# step: 241,       EMA radius error: 1px.       EMA center error: 3px
# step: 242,       EMA radius error: 1px.       EMA center error: 4px
# step: 243,       EMA radius error: 0px.       EMA center error: 10px
# step: 244,       EMA radius error: 8px.       EMA center error: 5px
# step: 245,       EMA radius error: 0px.       EMA center error: 1px
# step: 246,       EMA radius error: 11px.       EMA center error: 3px
# step: 247,       EMA radius error: 0px.       EMA center error: 4px
# step: 248,       EMA radius error: 0px.       EMA center error: 6px
# step: 249,       EMA radius error: 1px.       EMA center error: 5px
# step: 250,       EMA radius error: 0px.       EMA center error: 3px
# step: 251,       EMA radius error: 0px.       EMA center error: 2px
# step: 252,       EMA radius error: 1px.       EMA center error: 4px
# step: 253,       EMA radius error: 1px.       EMA center error: 2px
# step: 254,       EMA radius error: 1px.       EMA center error: 1px
# step: 255,       EMA radius error: 3px.       EMA center error: 2px
# step: 256,       EMA radius error: 2px.       EMA center error: 3px
# step: 257,       EMA radius error: 0px.       EMA center error: 3px
# step: 258,       EMA radius error: 1px.       EMA center error: 6px
# step: 259,       EMA radius error: 1px.       EMA center error: 2px
# step: 260,       EMA radius error: 1px.       EMA center error: 2px
# step: 261,       EMA radius error: 1px.       EMA center error: 3px
# step: 262,       EMA radius error: 0px.       EMA center error: 4px
# step: 263,       EMA radius error: 1px.       EMA center error: 3px
# step: 264,       EMA radius error: 1px.       EMA center error: 12px
# step: 265,       EMA radius error: 2px.       EMA center error: 1px
# step: 266,       EMA radius error: 1px.       EMA center error: 6px
# step: 267,       EMA radius error: 1px.       EMA center error: 3px
# step: 268,       EMA radius error: 5px.       EMA center error: 4px
# step: 269,       EMA radius error: 0px.       EMA center error: 2px
# step: 270,       EMA radius error: 9px.       EMA center error: 10px
# step: 271,       EMA radius error: 0px.       EMA center error: 1px
# step: 272,       EMA radius error: 1px.       EMA center error: 5px
# step: 273,       EMA radius error: 0px.       EMA center error: 7px
# step: 274,       EMA radius error: 5px.       EMA center error: 2px
# step: 275,       EMA radius error: 1px.       EMA center error: 6px
# step: 276,       EMA radius error: 1px.       EMA center error: 44px
# step: 277,       EMA radius error: 1px.       EMA center error: 7px
# step: 278,       EMA radius error: 1px.       EMA center error: 8px
# step: 279,       EMA radius error: 9px.       EMA center error: 9px
# step: 280,       EMA radius error: 1px.       EMA center error: 1px
# step: 281,       EMA radius error: 4px.       EMA center error: 2px
# step: 282,       EMA radius error: 0px.       EMA center error: 2px
# step: 283,       EMA radius error: 0px.       EMA center error: 6px
# step: 284,       EMA radius error: 1px.       EMA center error: 4px
# step: 285,       EMA radius error: 3px.       EMA center error: 3px
# step: 286,       EMA radius error: 0px.       EMA center error: 1px
# step: 287,       EMA radius error: 2px.       EMA center error: 0px
# step: 288,       EMA radius error: 0px.       EMA center error: 4px
# step: 289,       EMA radius error: 2px.       EMA center error: 1px
# step: 290,       EMA radius error: 0px.       EMA center error: 2px
# step: 291,       EMA radius error: 11px.       EMA center error: 2px
# step: 292,       EMA radius error: 1px.       EMA center error: 0px
# step: 293,       EMA radius error: 0px.       EMA center error: 1px
# step: 294,       EMA radius error: 0px.       EMA center error: 5px
# step: 295,       EMA radius error: 21px.       EMA center error: 5px
# step: 296,       EMA radius error: 0px.       EMA center error: 2px
# step: 297,       EMA radius error: 0px.       EMA center error: 4px
# step: 298,       EMA radius error: 0px.       EMA center error: 12px
# step: 299,       EMA radius error: 7px.       EMA center error: 3px
# step: 300,       EMA radius error: 3px.       EMA center error: 2px
# step: 301,       EMA radius error: 0px.       EMA center error: 2px
# step: 302,       EMA radius error: 0px.       EMA center error: 6px
# step: 303,       EMA radius error: 2px.       EMA center error: 2px
# step: 304,       EMA radius error: 1px.       EMA center error: 7px
# step: 305,       EMA radius error: 0px.       EMA center error: 8px
# step: 306,       EMA radius error: 3px.       EMA center error: 2px
# step: 307,       EMA radius error: 0px.       EMA center error: 8px
# step: 308,       EMA radius error: 0px.       EMA center error: 15px
# step: 309,       EMA radius error: 7px.       EMA center error: 5px
# step: 310,       EMA radius error: 8px.       EMA center error: 2px
# step: 311,       EMA radius error: 0px.       EMA center error: 1px
# step: 312,       EMA radius error: 5px.       EMA center error: 1px
# step: 313,       EMA radius error: 2px.       EMA center error: 4px
# step: 314,       EMA radius error: 15px.       EMA center error: 4px
# step: 315,       EMA radius error: 1px.       EMA center error: 7px
# step: 316,       EMA radius error: 0px.       EMA center error: 3px
# step: 317,       EMA radius error: 0px.       EMA center error: 1px
# step: 318,       EMA radius error: 0px.       EMA center error: 4px
# step: 319,       EMA radius error: 0px.       EMA center error: 1px
# step: 320,       EMA radius error: 3px.       EMA center error: 0px
# step: 321,       EMA radius error: 4px.       EMA center error: 5px
# step: 322,       EMA radius error: 0px.       EMA center error: 6px
# step: 323,       EMA radius error: 1px.       EMA center error: 3px
# step: 324,       EMA radius error: 10px.       EMA center error: 7px
# step: 325,       EMA radius error: 1px.       EMA center error: 2px
# step: 326,       EMA radius error: 1px.       EMA center error: 1px
# step: 327,       EMA radius error: 7px.       EMA center error: 2px
# step: 328,       EMA radius error: 3px.       EMA center error: 7px
# step: 329,       EMA radius error: 1px.       EMA center error: 1px
# step: 330,       EMA radius error: 3px.       EMA center error: 1px
# step: 331,       EMA radius error: 5px.       EMA center error: 3px
# step: 332,       EMA radius error: 5px.       EMA center error: 3px
# step: 333,       EMA radius error: 11px.       EMA center error: 7px
# step: 334,       EMA radius error: 1px.       EMA center error: 2px
# step: 335,       EMA radius error: 2px.       EMA center error: 0px
# step: 336,       EMA radius error: 0px.       EMA center error: 3px
# step: 337,       EMA radius error: 6px.       EMA center error: 3px
# step: 338,       EMA radius error: 0px.       EMA center error: 2px
# step: 339,       EMA radius error: 1px.       EMA center error: 0px
# step: 340,       EMA radius error: 0px.       EMA center error: 9px
# step: 341,       EMA radius error: 0px.       EMA center error: 13px
# step: 342,       EMA radius error: 4px.       EMA center error: 4px
# step: 343,       EMA radius error: 5px.       EMA center error: 2px
# step: 344,       EMA radius error: 5px.       EMA center error: 3px
# step: 345,       EMA radius error: 5px.       EMA center error: 4px
# step: 346,       EMA radius error: 16px.       EMA center error: 1px
# step: 347,       EMA radius error: 6px.       EMA center error: 1px
# step: 348,       EMA radius error: 0px.       EMA center error: 1px
# step: 349,       EMA radius error: 1px.       EMA center error: 1px
# step: 350,       EMA radius error: 0px.       EMA center error: 2px
# step: 351,       EMA radius error: 1px.       EMA center error: 2px
# step: 352,       EMA radius error: 0px.       EMA center error: 2px
# step: 353,       EMA radius error: 0px.       EMA center error: 4px
# step: 354,       EMA radius error: 1px.       EMA center error: 2px
# step: 355,       EMA radius error: 3px.       EMA center error: 5px
# step: 356,       EMA radius error: 0px.       EMA center error: 0px
# step: 357,       EMA radius error: 0px.       EMA center error: 2px
# step: 358,       EMA radius error: 0px.       EMA center error: 2px
# step: 359,       EMA radius error: 5px.       EMA center error: 4px
# step: 360,       EMA radius error: 0px.       EMA center error: 8px
# step: 361,       EMA radius error: 1px.       EMA center error: 3px
# step: 362,       EMA radius error: 2px.       EMA center error: 0px
# step: 363,       EMA radius error: 1px.       EMA center error: 0px
# step: 364,       EMA radius error: 1px.       EMA center error: 2px
# step: 365,       EMA radius error: 0px.       EMA center error: 1px
# step: 366,       EMA radius error: 2px.       EMA center error: 2px
# step: 367,       EMA radius error: 0px.       EMA center error: 2px
# step: 368,       EMA radius error: 1px.       EMA center error: 4px
# step: 369,       EMA radius error: 0px.       EMA center error: 9px
# step: 370,       EMA radius error: 0px.       EMA center error: 2px
# step: 371,       EMA radius error: 1px.       EMA center error: 2px
# step: 372,       EMA radius error: 0px.       EMA center error: 4px
# step: 373,       EMA radius error: 2px.       EMA center error: 1px
# step: 374,       EMA radius error: 0px.       EMA center error: 4px
# step: 375,       EMA radius error: 0px.       EMA center error: 16px
# step: 376,       EMA radius error: 5px.       EMA center error: 7px
# step: 377,       EMA radius error: 0px.       EMA center error: 1px
# step: 378,       EMA radius error: 0px.       EMA center error: 1px
# step: 379,       EMA radius error: 5px.       EMA center error: 1px
# step: 380,       EMA radius error: 0px.       EMA center error: 0px
# step: 381,       EMA radius error: 0px.       EMA center error: 4px
# step: 382,       EMA radius error: 0px.       EMA center error: 5px
# step: 383,       EMA radius error: 1px.       EMA center error: 4px
# step: 384,       EMA radius error: 1px.       EMA center error: 2px
# step: 385,       EMA radius error: 2px.       EMA center error: 2px
# step: 386,       EMA radius error: 1px.       EMA center error: 1px
# step: 387,       EMA radius error: 2px.       EMA center error: 7px
# step: 388,       EMA radius error: 1px.       EMA center error: 3px
# step: 389,       EMA radius error: 0px.       EMA center error: 2px
# step: 390,       EMA radius error: 4px.       EMA center error: 1px
# step: 391,       EMA radius error: 0px.       EMA center error: 1px
# step: 392,       EMA radius error: 0px.       EMA center error: 1px
# step: 393,       EMA radius error: 0px.       EMA center error: 2px
# step: 394,       EMA radius error: 2px.       EMA center error: 1px
# step: 395,       EMA radius error: 1px.       EMA center error: 2px
# step: 396,       EMA radius error: 2px.       EMA center error: 5px
# step: 397,       EMA radius error: 3px.       EMA center error: 3px
# step: 398,       EMA radius error: 1px.       EMA center error: 10px
# step: 399,       EMA radius error: 1px.       EMA center error: 1px
# step: 400,       EMA radius error: 0px.       EMA center error: 5px
# step: 401,       EMA radius error: 0px.       EMA center error: 3px
# step: 402,       EMA radius error: 1px.       EMA center error: 3px
# step: 403,       EMA radius error: 1px.       EMA center error: 1px
# step: 404,       EMA radius error: 0px.       EMA center error: 1px
# step: 405,       EMA radius error: 0px.       EMA center error: 3px
# step: 406,       EMA radius error: 0px.       EMA center error: 4px
# step: 407,       EMA radius error: 1px.       EMA center error: 1px
# step: 408,       EMA radius error: 0px.       EMA center error: 2px
# step: 409,       EMA radius error: 2px.       EMA center error: 2px
# step: 410,       EMA radius error: 1px.       EMA center error: 4px
# step: 411,       EMA radius error: 0px.       EMA center error: 1px
# step: 412,       EMA radius error: 0px.       EMA center error: 3px
# step: 413,       EMA radius error: 9px.       EMA center error: 7px
# step: 414,       EMA radius error: 0px.       EMA center error: 2px
# step: 415,       EMA radius error: 0px.       EMA center error: 2px
# step: 416,       EMA radius error: 0px.       EMA center error: 1px
# step: 417,       EMA radius error: 0px.       EMA center error: 3px
# step: 418,       EMA radius error: 3px.       EMA center error: 1px
# step: 419,       EMA radius error: 0px.       EMA center error: 1px
# step: 420,       EMA radius error: 1px.       EMA center error: 0px
# step: 421,       EMA radius error: 0px.       EMA center error: 3px
# step: 422,       EMA radius error: 1px.       EMA center error: 3px
# step: 423,       EMA radius error: 8px.       EMA center error: 0px
# step: 424,       EMA radius error: 1px.       EMA center error: 3px
# step: 425,       EMA radius error: 1px.       EMA center error: 2px
# step: 426,       EMA radius error: 0px.       EMA center error: 2px
# step: 427,       EMA radius error: 0px.       EMA center error: 2px
# step: 428,       EMA radius error: 0px.       EMA center error: 1px
# step: 429,       EMA radius error: 0px.       EMA center error: 2px
# step: 430,       EMA radius error: 1px.       EMA center error: 0px
# step: 431,       EMA radius error: 1px.       EMA center error: 3px
# step: 432,       EMA radius error: 0px.       EMA center error: 6px
# step: 433,       EMA radius error: 2px.       EMA center error: 0px
# step: 434,       EMA radius error: 0px.       EMA center error: 3px
# step: 435,       EMA radius error: 0px.       EMA center error: 3px
# step: 436,       EMA radius error: 1px.       EMA center error: 2px
# step: 437,       EMA radius error: 0px.       EMA center error: 1px
# step: 438,       EMA radius error: 0px.       EMA center error: 4px
# step: 439,       EMA radius error: 1px.       EMA center error: 2px
# step: 440,       EMA radius error: 2px.       EMA center error: 5px
# step: 441,       EMA radius error: 1px.       EMA center error: 3px
# step: 442,       EMA radius error: 0px.       EMA center error: 0px
# step: 443,       EMA radius error: 0px.       EMA center error: 1px
# step: 444,       EMA radius error: 2px.       EMA center error: 1px
# step: 445,       EMA radius error: 1px.       EMA center error: 2px
# step: 446,       EMA radius error: 0px.       EMA center error: 8px
# step: 447,       EMA radius error: 3px.       EMA center error: 1px
# step: 448,       EMA radius error: 1px.       EMA center error: 0px
# step: 449,       EMA radius error: 3px.       EMA center error: 1px
# step: 450,       EMA radius error: 3px.       EMA center error: 1px
# step: 451,       EMA radius error: 1px.       EMA center error: 0px
# step: 452,       EMA radius error: 1px.       EMA center error: 1px
# step: 453,       EMA radius error: 1px.       EMA center error: 5px
# step: 454,       EMA radius error: 0px.       EMA center error: 5px
# step: 455,       EMA radius error: 3px.       EMA center error: 2px
# step: 456,       EMA radius error: 0px.       EMA center error: 2px
# step: 457,       EMA radius error: 2px.       EMA center error: 1px
# step: 458,       EMA radius error: 0px.       EMA center error: 7px
# step: 459,       EMA radius error: 0px.       EMA center error: 2px
# step: 460,       EMA radius error: 1px.       EMA center error: 3px
# step: 461,       EMA radius error: 0px.       EMA center error: 5px
# step: 462,       EMA radius error: 0px.       EMA center error: 0px
# step: 463,       EMA radius error: 1px.       EMA center error: 3px
# step: 464,       EMA radius error: 2px.       EMA center error: 1px
# step: 465,       EMA radius error: 0px.       EMA center error: 0px
# step: 466,       EMA radius error: 0px.       EMA center error: 0px
# step: 467,       EMA radius error: 2px.       EMA center error: 1px
# step: 468,       EMA radius error: 1px.       EMA center error: 4px
# step: 469,       EMA radius error: 1px.       EMA center error: 3px
# step: 470,       EMA radius error: 0px.       EMA center error: 0px
# step: 471,       EMA radius error: 0px.       EMA center error: 1px
# step: 472,       EMA radius error: 0px.       EMA center error: 2px
# step: 473,       EMA radius error: 1px.       EMA center error: 2px
# step: 474,       EMA radius error: 0px.       EMA center error: 2px
# step: 475,       EMA radius error: 1px.       EMA center error: 1px
# step: 476,       EMA radius error: 0px.       EMA center error: 3px
# step: 477,       EMA radius error: 5px.       EMA center error: 2px
# step: 478,       EMA radius error: 0px.       EMA center error: 0px
# step: 479,       EMA radius error: 1px.       EMA center error: 1px
# step: 480,       EMA radius error: 16px.       EMA center error: 0px
# step: 481,       EMA radius error: 0px.       EMA center error: 6px
# step: 482,       EMA radius error: 0px.       EMA center error: 2px
# step: 483,       EMA radius error: 0px.       EMA center error: 3px
# step: 484,       EMA radius error: 2px.       EMA center error: 2px
# step: 485,       EMA radius error: 2px.       EMA center error: 1px
# step: 486,       EMA radius error: 1px.       EMA center error: 3px
# step: 487,       EMA radius error: 2px.       EMA center error: 1px
# step: 488,       EMA radius error: 1px.       EMA center error: 1px
# step: 489,       EMA radius error: 2px.       EMA center error: 4px
# step: 490,       EMA radius error: 3px.       EMA center error: 8px
# step: 491,       EMA radius error: 0px.       EMA center error: 4px
# step: 492,       EMA radius error: 0px.       EMA center error: 2px
# step: 493,       EMA radius error: 0px.       EMA center error: 2px
# step: 494,       EMA radius error: 1px.       EMA center error: 7px
# step: 495,       EMA radius error: 3px.       EMA center error: 3px
# step: 496,       EMA radius error: 2px.       EMA center error: 4px
# step: 497,       EMA radius error: 1px.       EMA center error: 2px
# step: 498,       EMA radius error: 1px.       EMA center error: 1px
# step: 499,       EMA radius error: 0px.       EMA center error: 2px
# step: 500,       EMA radius error: 1px.       EMA center error: 3px
# step: 501,       EMA radius error: 2px.       EMA center error: 4px
# step: 502,       EMA radius error: 1px.       EMA center error: 5px
# step: 503,       EMA radius error: 0px.       EMA center error: 3px
# step: 504,       EMA radius error: 0px.       EMA center error: 1px
# step: 505,       EMA radius error: 0px.       EMA center error: 4px
# step: 506,       EMA radius error: 0px.       EMA center error: 1px
# step: 507,       EMA radius error: 0px.       EMA center error: 3px
# step: 508,       EMA radius error: 0px.       EMA center error: 3px
# step: 509,       EMA radius error: 3px.       EMA center error: 1px
# step: 510,       EMA radius error: 0px.       EMA center error: 1px
# step: 511,       EMA radius error: 0px.       EMA center error: 1px
# step: 512,       EMA radius error: 0px.       EMA center error: 3px
# step: 513,       EMA radius error: 0px.       EMA center error: 1px
# step: 514,       EMA radius error: 0px.       EMA center error: 2px
# step: 515,       EMA radius error: 2px.       EMA center error: 6px
# step: 516,       EMA radius error: 2px.       EMA center error: 13px
# step: 517,       EMA radius error: 0px.       EMA center error: 1px
# step: 518,       EMA radius error: 1px.       EMA center error: 5px
# step: 519,       EMA radius error: 2px.       EMA center error: 3px
# step: 520,       EMA radius error: 0px.       EMA center error: 3px
# step: 521,       EMA radius error: 0px.       EMA center error: 4px
# step: 522,       EMA radius error: 0px.       EMA center error: 1px
# step: 523,       EMA radius error: 1px.       EMA center error: 4px
# step: 524,       EMA radius error: 0px.       EMA center error: 1px
# step: 525,       EMA radius error: 0px.       EMA center error: 2px
# step: 526,       EMA radius error: 5px.       EMA center error: 2px
# step: 527,       EMA radius error: 0px.       EMA center error: 3px
# step: 528,       EMA radius error: 5px.       EMA center error: 1px
# step: 529,       EMA radius error: 2px.       EMA center error: 3px
# step: 530,       EMA radius error: 1px.       EMA center error: 3px
# step: 531,       EMA radius error: 0px.       EMA center error: 5px
# step: 532,       EMA radius error: 0px.       EMA center error: 2px
# step: 533,       EMA radius error: 1px.       EMA center error: 1px
# step: 534,       EMA radius error: 0px.       EMA center error: 1px
# step: 535,       EMA radius error: 0px.       EMA center error: 3px
# step: 536,       EMA radius error: 1px.       EMA center error: 1px
# step: 537,       EMA radius error: 0px.       EMA center error: 3px
# step: 538,       EMA radius error: 0px.       EMA center error: 4px
# step: 539,       EMA radius error: 0px.       EMA center error: 0px
# step: 540,       EMA radius error: 0px.       EMA center error: 0px
# step: 541,       EMA radius error: 0px.       EMA center error: 0px
# step: 542,       EMA radius error: 0px.       EMA center error: 2px
# step: 543,       EMA radius error: 2px.       EMA center error: 1px
# step: 544,       EMA radius error: 0px.       EMA center error: 2px
# step: 545,       EMA radius error: 1px.       EMA center error: 5px
# step: 546,       EMA radius error: 0px.       EMA center error: 4px
# step: 547,       EMA radius error: 0px.       EMA center error: 1px
# step: 548,       EMA radius error: 1px.       EMA center error: 2px
# step: 549,       EMA radius error: 2px.       EMA center error: 4px
# step: 550,       EMA radius error: 1px.       EMA center error: 3px
# step: 551,       EMA radius error: 0px.       EMA center error: 0px
# step: 552,       EMA radius error: 2px.       EMA center error: 6px
# step: 553,       EMA radius error: 0px.       EMA center error: 3px
# step: 554,       EMA radius error: 1px.       EMA center error: 2px
# step: 555,       EMA radius error: 0px.       EMA center error: 0px
# step: 556,       EMA radius error: 2px.       EMA center error: 4px
# step: 557,       EMA radius error: 3px.       EMA center error: 1px
# step: 558,       EMA radius error: 0px.       EMA center error: 0px
# step: 559,       EMA radius error: 0px.       EMA center error: 3px
# step: 560,       EMA radius error: 0px.       EMA center error: 1px
# step: 561,       EMA radius error: 0px.       EMA center error: 2px
# step: 562,       EMA radius error: 2px.       EMA center error: 1px
# step: 563,       EMA radius error: 1px.       EMA center error: 1px
# step: 564,       EMA radius error: 2px.       EMA center error: 4px
# step: 565,       EMA radius error: 0px.       EMA center error: 9px
# step: 566,       EMA radius error: 0px.       EMA center error: 1px
# step: 567,       EMA radius error: 1px.       EMA center error: 5px
# step: 568,       EMA radius error: 1px.       EMA center error: 1px
# step: 569,       EMA radius error: 2px.       EMA center error: 3px
# step: 570,       EMA radius error: 2px.       EMA center error: 2px
# step: 571,       EMA radius error: 1px.       EMA center error: 1px
# step: 572,       EMA radius error: 2px.       EMA center error: 1px
# step: 573,       EMA radius error: 0px.       EMA center error: 3px
# step: 574,       EMA radius error: 1px.       EMA center error: 5px
# step: 575,       EMA radius error: 1px.       EMA center error: 1px
# step: 576,       EMA radius error: 0px.       EMA center error: 1px
# step: 577,       EMA radius error: 1px.       EMA center error: 1px
# step: 578,       EMA radius error: 0px.       EMA center error: 2px
# step: 579,       EMA radius error: 0px.       EMA center error: 2px
# step: 580,       EMA radius error: 0px.       EMA center error: 2px
# step: 581,       EMA radius error: 1px.       EMA center error: 2px
# step: 582,       EMA radius error: 1px.       EMA center error: 1px
# step: 583,       EMA radius error: 2px.       EMA center error: 1px
# step: 584,       EMA radius error: 0px.       EMA center error: 8px
# step: 585,       EMA radius error: 2px.       EMA center error: 3px
# step: 586,       EMA radius error: 0px.       EMA center error: 1px
# step: 587,       EMA radius error: 1px.       EMA center error: 1px
# step: 588,       EMA radius error: 0px.       EMA center error: 1px
# step: 589,       EMA radius error: 0px.       EMA center error: 1px
# step: 590,       EMA radius error: 0px.       EMA center error: 1px
# step: 591,       EMA radius error: 1px.       EMA center error: 1px
# step: 592,       EMA radius error: 0px.       EMA center error: 2px
# step: 593,       EMA radius error: 0px.       EMA center error: 1px
# step: 594,       EMA radius error: 8px.       EMA center error: 1px
# step: 595,       EMA radius error: 4px.       EMA center error: 2px
# step: 596,       EMA radius error: 2px.       EMA center error: 1px
# step: 597,       EMA radius error: 0px.       EMA center error: 1px
# step: 598,       EMA radius error: 0px.       EMA center error: 2px
# step: 599,       EMA radius error: 3px.       EMA center error: 1px
# step: 600,       EMA radius error: 0px.       EMA center error: 0px
# step: 601,       EMA radius error: 1px.       EMA center error: 2px
# step: 602,       EMA radius error: 2px.       EMA center error: 1px
# step: 603,       EMA radius error: 0px.       EMA center error: 1px
# step: 604,       EMA radius error: 0px.       EMA center error: 2px
# step: 605,       EMA radius error: 1px.       EMA center error: 7px
# step: 606,       EMA radius error: 2px.       EMA center error: 2px
# step: 607,       EMA radius error: 0px.       EMA center error: 6px
# step: 608,       EMA radius error: 5px.       EMA center error: 1px
# step: 609,       EMA radius error: 1px.       EMA center error: 2px
# step: 610,       EMA radius error: 5px.       EMA center error: 5px
# step: 611,       EMA radius error: 7px.       EMA center error: 1px
# step: 612,       EMA radius error: 2px.       EMA center error: 3px
# step: 613,       EMA radius error: 1px.       EMA center error: 7px
# step: 614,       EMA radius error: 0px.       EMA center error: 8px
# step: 615,       EMA radius error: 0px.       EMA center error: 5px
# step: 616,       EMA radius error: 4px.       EMA center error: 1px
# step: 617,       EMA radius error: 9px.       EMA center error: 1px
# step: 618,       EMA radius error: 2px.       EMA center error: 3px
# step: 619,       EMA radius error: 4px.       EMA center error: 1px
# step: 620,       EMA radius error: 0px.       EMA center error: 4px
# step: 621,       EMA radius error: 2px.       EMA center error: 1px
# step: 622,       EMA radius error: 2px.       EMA center error: 5px
# step: 623,       EMA radius error: 0px.       EMA center error: 5px
# step: 624,       EMA radius error: 1px.       EMA center error: 11px
# step: 625,       EMA radius error: 0px.       EMA center error: 5px
# step: 626,       EMA radius error: 7px.       EMA center error: 2px
# step: 627,       EMA radius error: 2px.       EMA center error: 3px
# step: 628,       EMA radius error: 2px.       EMA center error: 11px
# step: 629,       EMA radius error: 9px.       EMA center error: 1px
# step: 630,       EMA radius error: 1px.       EMA center error: 5px
# step: 631,       EMA radius error: 3px.       EMA center error: 5px
# step: 632,       EMA radius error: 8px.       EMA center error: 11px
# step: 633,       EMA radius error: 1px.       EMA center error: 0px
# step: 634,       EMA radius error: 11px.       EMA center error: 2px
# step: 635,       EMA radius error: 11px.       EMA center error: 3px
# step: 636,       EMA radius error: 1px.       EMA center error: 1px
# step: 637,       EMA radius error: 0px.       EMA center error: 4px
# step: 638,       EMA radius error: 2px.       EMA center error: 1px
# step: 639,       EMA radius error: 1px.       EMA center error: 1px
# step: 640,       EMA radius error: 1px.       EMA center error: 1px
# step: 641,       EMA radius error: 2px.       EMA center error: 2px
# step: 642,       EMA radius error: 0px.       EMA center error: 4px
# step: 643,       EMA radius error: 3px.       EMA center error: 2px
# step: 644,       EMA radius error: 3px.       EMA center error: 1px
# step: 645,       EMA radius error: 7px.       EMA center error: 2px
# step: 646,       EMA radius error: 1px.       EMA center error: 3px
# step: 647,       EMA radius error: 0px.       EMA center error: 2px
# step: 648,       EMA radius error: 3px.       EMA center error: 1px
# step: 649,       EMA radius error: 0px.       EMA center error: 8px
# step: 650,       EMA radius error: 0px.       EMA center error: 1px
# step: 651,       EMA radius error: 0px.       EMA center error: 2px
# step: 652,       EMA radius error: 0px.       EMA center error: 3px
# step: 653,       EMA radius error: 1px.       EMA center error: 1px
# step: 654,       EMA radius error: 1px.       EMA center error: 2px
# step: 655,       EMA radius error: 0px.       EMA center error: 6px
# step: 656,       EMA radius error: 0px.       EMA center error: 1px
# step: 657,       EMA radius error: 4px.       EMA center error: 3px
# step: 658,       EMA radius error: 0px.       EMA center error: 1px
# step: 659,       EMA radius error: 0px.       EMA center error: 8px
# step: 660,       EMA radius error: 1px.       EMA center error: 5px
# step: 661,       EMA radius error: 0px.       EMA center error: 1px
# step: 662,       EMA radius error: 2px.       EMA center error: 1px
# step: 663,       EMA radius error: 2px.       EMA center error: 2px
# step: 664,       EMA radius error: 1px.       EMA center error: 1px
# step: 665,       EMA radius error: 1px.       EMA center error: 5px
# step: 666,       EMA radius error: 1px.       EMA center error: 3px
# step: 667,       EMA radius error: 2px.       EMA center error: 3px
# step: 668,       EMA radius error: 1px.       EMA center error: 1px
# step: 669,       EMA radius error: 0px.       EMA center error: 4px
# step: 670,       EMA radius error: 3px.       EMA center error: 1px
# step: 671,       EMA radius error: 3px.       EMA center error: 0px
# step: 672,       EMA radius error: 1px.       EMA center error: 10px
# step: 673,       EMA radius error: 0px.       EMA center error: 4px
# step: 674,       EMA radius error: 0px.       EMA center error: 2px
# step: 675,       EMA radius error: 1px.       EMA center error: 0px
# step: 676,       EMA radius error: 2px.       EMA center error: 1px
# step: 677,       EMA radius error: 0px.       EMA center error: 2px
# step: 678,       EMA radius error: 0px.       EMA center error: 2px
# step: 679,       EMA radius error: 1px.       EMA center error: 1px
# step: 680,       EMA radius error: 3px.       EMA center error: 3px
# step: 681,       EMA radius error: 5px.       EMA center error: 1px
# step: 682,       EMA radius error: 0px.       EMA center error: 0px
# step: 683,       EMA radius error: 0px.       EMA center error: 1px
# step: 684,       EMA radius error: 0px.       EMA center error: 0px
# step: 685,       EMA radius error: 0px.       EMA center error: 1px
# step: 686,       EMA radius error: 0px.       EMA center error: 2px
# step: 687,       EMA radius error: 1px.       EMA center error: 0px
# step: 688,       EMA radius error: 0px.       EMA center error: 2px
# step: 689,       EMA radius error: 0px.       EMA center error: 1px
# step: 690,       EMA radius error: 0px.       EMA center error: 1px
# step: 691,       EMA radius error: 0px.       EMA center error: 1px
# step: 692,       EMA radius error: 1px.       EMA center error: 0px
# step: 693,       EMA radius error: 1px.       EMA center error: 2px
# step: 694,       EMA radius error: 0px.       EMA center error: 4px
# step: 695,       EMA radius error: 5px.       EMA center error: 4px
# step: 696,       EMA radius error: 0px.       EMA center error: 1px
# step: 697,       EMA radius error: 0px.       EMA center error: 2px
# step: 698,       EMA radius error: 0px.       EMA center error: 1px
# step: 699,       EMA radius error: 0px.       EMA center error: 6px
# step: 700,       EMA radius error: 2px.       EMA center error: 1px
# step: 701,       EMA radius error: 0px.       EMA center error: 2px
# step: 702,       EMA radius error: 1px.       EMA center error: 1px
# step: 703,       EMA radius error: 0px.       EMA center error: 1px
# step: 704,       EMA radius error: 0px.       EMA center error: 2px
# step: 705,       EMA radius error: 0px.       EMA center error: 1px
# ...
# step: 765,       EMA radius error: 0px.       EMA center error: 3px
# step: 766,       EMA radius error: 0px.       EMA center error: 1px
# step: 767,       EMA radius error: 0px.       EMA center error: 2px
# step: 768,       EMA radius error: 0px.       EMA center error: 1px
# step: 769,       EMA radius error: 0px.       EMA center error: 3px
# step: 770,       EMA radius error: 0px.       EMA center error: 1px
# step: 771,       EMA radius error: 0px.       EMA center error: 1px
# step: 772,       EMA radius error: 1px.       EMA center error: 2px
# step: 773,       EMA radius error: 0px.       EMA center error: 2px
# step: 774,       EMA radius error: 0px.       EMA center error: 1px
# step: 775,       EMA radius error: 0px.       EMA center error: 2px
# step: 776,       EMA radius error: 0px.       EMA center error: 0px
# step: 777,       EMA radius error: 0px.       EMA center error: 0px
# step: 778,       EMA radius error: 0px.       EMA center error: 2px
# step: 779,       EMA radius error: 0px.       EMA center error: 2px
# step: 780,       EMA radius error: 1px.       EMA center error: 3px
# step: 781,       EMA radius error: 0px.       EMA center error: 7px
# step: 782,       EMA radius error: 0px.       EMA center error: 2px
# step: 783,       EMA radius error: 1px.       EMA center error: 0px
# step: 784,       EMA radius error: 1px.       EMA center error: 1px
# step: 785,       EMA radius error: 4px.       EMA center error: 1px
# step: 786,       EMA radius error: 3px.       EMA center error: 0px
# step: 787,       EMA radius error: 0px.       EMA center error: 6px
# step: 788,       EMA radius error: 0px.       EMA center error: 5px
# step: 789,       EMA radius error: 0px.       EMA center error: 1px
# step: 790,       EMA radius error: 3px.       EMA center error: 2px
# step: 791,       EMA radius error: 1px.       EMA center error: 2px
# step: 792,       EMA radius error: 3px.       EMA center error: 2px
# step: 793,       EMA radius error: 4px.       EMA center error: 2px
# step: 794,       EMA radius error: 2px.       EMA center error: 2px
# step: 795,       EMA radius error: 0px.       EMA center error: 3px
# step: 796,       EMA radius error: 0px.       EMA center error: 1px
# step: 797,       EMA radius error: 0px.       EMA center error: 2px
# step: 798,       EMA radius error: 6px.       EMA center error: 1px
# step: 799,       EMA radius error: 1px.       EMA center error: 2px
# step: 800,       EMA radius error: 0px.       EMA center error: 8px
# step: 801,       EMA radius error: 1px.       EMA center error: 2px
# step: 802,       EMA radius error: 1px.       EMA center error: 0px
# step: 803,       EMA radius error: 1px.       EMA center error: 4px
# step: 804,       EMA radius error: 0px.       EMA center error: 1px
# step: 805,       EMA radius error: 0px.       EMA center error: 2px
# step: 806,       EMA radius error: 1px.       EMA center error: 1px
# step: 807,       EMA radius error: 0px.       EMA center error: 1px
# step: 808,       EMA radius error: 0px.       EMA center error: 2px
# step: 809,       EMA radius error: 0px.       EMA center error: 2px
# step: 810,       EMA radius error: 0px.       EMA center error: 0px
# step: 811,       EMA radius error: 1px.       EMA center error: 3px
# step: 812,       EMA radius error: 0px.       EMA center error: 2px
# step: 813,       EMA radius error: 0px.       EMA center error: 4px
# step: 814,       EMA radius error: 1px.       EMA center error: 2px
# step: 815,       EMA radius error: 1px.       EMA center error: 1px
# step: 816,       EMA radius error: 1px.       EMA center error: 3px
# step: 817,       EMA radius error: 2px.       EMA center error: 2px
# step: 818,       EMA radius error: 48px.       EMA center error: 1px
# step: 819,       EMA radius error: 0px.       EMA center error: 1px
# step: 820,       EMA radius error: 0px.       EMA center error: 2px
# step: 821,       EMA radius error: 0px.       EMA center error: 0px
# step: 822,       EMA radius error: 1px.       EMA center error: 1px
# step: 823,       EMA radius error: 0px.       EMA center error: 8px
# step: 824,       EMA radius error: 1px.       EMA center error: 0px
# step: 825,       EMA radius error: 1px.       EMA center error: 0px
# step: 826,       EMA radius error: 7px.       EMA center error: 1px
# step: 827,       EMA radius error: 1px.       EMA center error: 2px
# step: 828,       EMA radius error: 1px.       EMA center error: 11px
# step: 829,       EMA radius error: 0px.       EMA center error: 8px
# step: 830,       EMA radius error: 0px.       EMA center error: 1px
# step: 831,       EMA radius error: 4px.       EMA center error: 6px
# step: 832,       EMA radius error: 3px.       EMA center error: 0px
# step: 833,       EMA radius error: 2px.       EMA center error: 2px
# step: 834,       EMA radius error: 0px.       EMA center error: 2px
# step: 835,       EMA radius error: 2px.       EMA center error: 1px
# step: 836,       EMA radius error: 5px.       EMA center error: 0px
# step: 837,       EMA radius error: 1px.       EMA center error: 1px
# step: 838,       EMA radius error: 1px.       EMA center error: 3px
# step: 839,       EMA radius error: 0px.       EMA center error: 3px
# step: 840,       EMA radius error: 1px.       EMA center error: 5px
# step: 841,       EMA radius error: 0px.       EMA center error: 2px
# step: 842,       EMA radius error: 4px.       EMA center error: 10px
# step: 843,       EMA radius error: 2px.       EMA center error: 1px
# step: 844,       EMA radius error: 0px.       EMA center error: 2px
# step: 845,       EMA radius error: 1px.       EMA center error: 2px
# step: 846,       EMA radius error: 1px.       EMA center error: 4px
# step: 847,       EMA radius error: 6px.       EMA center error: 1px
# step: 848,       EMA radius error: 0px.       EMA center error: 2px
# step: 849,       EMA radius error: 0px.       EMA center error: 1px
# step: 850,       EMA radius error: 0px.       EMA center error: 11px
# step: 851,       EMA radius error: 5px.       EMA center error: 1px
# step: 852,       EMA radius error: 1px.       EMA center error: 2px
# step: 853,       EMA radius error: 0px.       EMA center error: 3px
# step: 854,       EMA radius error: 3px.       EMA center error: 3px
# step: 855,       EMA radius error: 2px.       EMA center error: 4px
# step: 856,       EMA radius error: 1px.       EMA center error: 3px
# step: 857,       EMA radius error: 4px.       EMA center error: 0px
# step: 858,       EMA radius error: 1px.       EMA center error: 3px
# step: 859,       EMA radius error: 1px.       EMA center error: 1px
# step: 860,       EMA radius error: 0px.       EMA center error: 6px
# step: 861,       EMA radius error: 0px.       EMA center error: 3px
# step: 862,       EMA radius error: 0px.       EMA center error: 2px
# step: 863,       EMA radius error: 0px.       EMA center error: 2px
# step: 864,       EMA radius error: 1px.       EMA center error: 0px
# step: 865,       EMA radius error: 0px.       EMA center error: 5px
# step: 866,       EMA radius error: 0px.       EMA center error: 4px
# step: 867,       EMA radius error: 1px.       EMA center error: 5px
# step: 868,       EMA radius error: 0px.       EMA center error: 6px
# step: 869,       EMA radius error: 0px.       EMA center error: 3px
# step: 870,       EMA radius error: 1px.       EMA center error: 4px
# step: 871,       EMA radius error: 4px.       EMA center error: 2px
# step: 872,       EMA radius error: 0px.       EMA center error: 6px
# step: 873,       EMA radius error: 1px.       EMA center error: 3px
# step: 874,       EMA radius error: 0px.       EMA center error: 1px
# step: 875,       EMA radius error: 0px.       EMA center error: 2px
# step: 876,       EMA radius error: 0px.       EMA center error: 5px
# step: 877,       EMA radius error: 1px.       EMA center error: 2px
# step: 878,       EMA radius error: 0px.       EMA center error: 4px
# step: 879,       EMA radius error: 1px.       EMA center error: 4px
# step: 880,       EMA radius error: 0px.       EMA center error: 1px
# step: 881,       EMA radius error: 0px.       EMA center error: 2px
# step: 882,       EMA radius error: 1px.       EMA center error: 1px
# step: 883,       EMA radius error: 0px.       EMA center error: 2px
# step: 884,       EMA radius error: 2px.       EMA center error: 1px
# step: 885,       EMA radius error: 0px.       EMA center error: 3px
# step: 886,       EMA radius error: 1px.       EMA center error: 5px
# step: 887,       EMA radius error: 0px.       EMA center error: 1px
# step: 888,       EMA radius error: 0px.       EMA center error: 3px
# step: 889,       EMA radius error: 0px.       EMA center error: 1px
# step: 890,       EMA radius error: 0px.       EMA center error: 1px
# step: 891,       EMA radius error: 0px.       EMA center error: 5px
# step: 892,       EMA radius error: 0px.       EMA center error: 1px
# step: 893,       EMA radius error: 1px.       EMA center error: 1px
# step: 894,       EMA radius error: 0px.       EMA center error: 1px
# step: 895,       EMA radius error: 0px.       EMA center error: 1px
# step: 896,       EMA radius error: 0px.       EMA center error: 2px
# step: 897,       EMA radius error: 0px.       EMA center error: 3px
# step: 898,       EMA radius error: 1px.       EMA center error: 2px
# step: 899,       EMA radius error: 1px.       EMA center error: 2px
# step: 900,       EMA radius error: 0px.       EMA center error: 1px
# step: 901,       EMA radius error: 1px.       EMA center error: 1px
# step: 902,       EMA radius error: 1px.       EMA center error: 7px
# step: 903,       EMA radius error: 0px.       EMA center error: 1px
# step: 904,       EMA radius error: 0px.       EMA center error: 3px
# step: 905,       EMA radius error: 0px.       EMA center error: 2px
# step: 906,       EMA radius error: 0px.       EMA center error: 1px
# step: 907,       EMA radius error: 0px.       EMA center error: 1px
# step: 908,       EMA radius error: 0px.       EMA center error: 4px
# step: 909,       EMA radius error: 1px.       EMA center error: 1px
# step: 910,       EMA radius error: 0px.       EMA center error: 2px
# step: 911,       EMA radius error: 2px.       EMA center error: 6px
# step: 912,       EMA radius error: 1px.       EMA center error: 2px
# step: 913,       EMA radius error: 0px.       EMA center error: 1px
# step: 914,       EMA radius error: 0px.       EMA center error: 1px
# step: 915,       EMA radius error: 0px.       EMA center error: 4px
# step: 916,       EMA radius error: 0px.       EMA center error: 3px
# step: 917,       EMA radius error: 2px.       EMA center error: 3px
# step: 918,       EMA radius error: 2px.       EMA center error: 2px
# step: 919,       EMA radius error: 1px.       EMA center error: 1px
# step: 920,       EMA radius error: 0px.       EMA center error: 1px
# step: 921,       EMA radius error: 0px.       EMA center error: 3px
# step: 922,       EMA radius error: 0px.       EMA center error: 1px
# step: 923,       EMA radius error: 0px.       EMA center error: 2px
# step: 924,       EMA radius error: 1px.       EMA center error: 2px
# step: 925,       EMA radius error: 2px.       EMA center error: 1px
# step: 926,       EMA radius error: 0px.       EMA center error: 1px
# step: 927,       EMA radius error: 0px.       EMA center error: 6px
# step: 928,       EMA radius error: 3px.       EMA center error: 1px
# step: 929,       EMA radius error: 1px.       EMA center error: 3px
# step: 930,       EMA radius error: 5px.       EMA center error: 12px
# step: 931,       EMA radius error: 3px.       EMA center error: 3px
# step: 932,       EMA radius error: 2px.       EMA center error: 1px
# step: 933,       EMA radius error: 1px.       EMA center error: 2px
# step: 934,       EMA radius error: 1px.       EMA center error: 2px
# step: 935,       EMA radius error: 0px.       EMA center error: 1px
# step: 936,       EMA radius error: 0px.       EMA center error: 1px
# step: 937,       EMA radius error: 0px.       EMA center error: 1px
# step: 938,       EMA radius error: 1px.       EMA center error: 2px
# step: 939,       EMA radius error: 6px.       EMA center error: 1px
# step: 940,       EMA radius error: 0px.       EMA center error: 2px
# step: 941,       EMA radius error: 0px.       EMA center error: 6px
# step: 942,       EMA radius error: 8px.       EMA center error: 1px
# step: 943,       EMA radius error: 1px.       EMA center error: 3px
# step: 944,       EMA radius error: 0px.       EMA center error: 1px
# step: 945,       EMA radius error: 0px.       EMA center error: 2px
# step: 946,       EMA radius error: 0px.       EMA center error: 1px
# step: 947,       EMA radius error: 0px.       EMA center error: 2px
# step: 948,       EMA radius error: 1px.       EMA center error: 4px
# step: 949,       EMA radius error: 4px.       EMA center error: 1px
# step: 950,       EMA radius error: 1px.       EMA center error: 1px
# step: 951,       EMA radius error: 0px.       EMA center error: 1px
# step: 952,       EMA radius error: 0px.       EMA center error: 3px
# step: 953,       EMA radius error: 0px.       EMA center error: 3px
# step: 954,       EMA radius error: 2px.       EMA center error: 2px
# step: 955,       EMA radius error: 3px.       EMA center error: 0px
# step: 956,       EMA radius error: 4px.       EMA center error: 1px
# step: 957,       EMA radius error: 4px.       EMA center error: 0px
# step: 958,       EMA radius error: 0px.       EMA center error: 1px
# step: 959,       EMA radius error: 2px.       EMA center error: 4px
# step: 960,       EMA radius error: 2px.       EMA center error: 1px
# step: 961,       EMA radius error: 1px.       EMA center error: 4px
# step: 962,       EMA radius error: 0px.       EMA center error: 2px
# step: 963,       EMA radius error: 1px.       EMA center error: 2px
# step: 964,       EMA radius error: 1px.       EMA center error: 1px
# step: 965,       EMA radius error: 0px.       EMA center error: 2px
# step: 966,       EMA radius error: 0px.       EMA center error: 0px
# step: 967,       EMA radius error: 2px.       EMA center error: 2px
# step: 968,       EMA radius error: 1px.       EMA center error: 0px
# step: 969,       EMA radius error: 1px.       EMA center error: 0px
# step: 970,       EMA radius error: 1px.       EMA center error: 6px
# step: 971,       EMA radius error: 1px.       EMA center error: 2px
# step: 972,       EMA radius error: 2px.       EMA center error: 1px
# step: 973,       EMA radius error: 0px.       EMA center error: 2px
# step: 974,       EMA radius error: 0px.       EMA center error: 2px
# step: 975,       EMA radius error: 0px.       EMA center error: 2px
# step: 976,       EMA radius error: 0px.       EMA center error: 4px
# step: 977,       EMA radius error: 0px.       EMA center error: 2px
# step: 978,       EMA radius error: 0px.       EMA center error: 1px
# step: 979,       EMA radius error: 0px.       EMA center error: 0px
# step: 980,       EMA radius error: 3px.       EMA center error: 1px
# step: 981,       EMA radius error: 2px.       EMA center error: 1px
# step: 982,       EMA radius error: 0px.       EMA center error: 1px
# step: 983,       EMA radius error: 1px.       EMA center error: 1px
# step: 984,       EMA radius error: 1px.       EMA center error: 1px
# step: 985,       EMA radius error: 0px.       EMA center error: 0px
# step: 986,       EMA radius error: 1px.       EMA center error: 1px
# step: 987,       EMA radius error: 0px.       EMA center error: 1px
# step: 988,       EMA radius error: 0px.       EMA center error: 1px
# step: 989,       EMA radius error: 0px.       EMA center error: 1px
# step: 990,       EMA radius error: 1px.       EMA center error: 1px
# step: 991,       EMA radius error: 0px.       EMA center error: 0px
# step: 992,       EMA radius error: 3px.       EMA center error: 1px
# step: 993,       EMA radius error: 0px.       EMA center error: 0px
# step: 994,       EMA radius error: 0px.       EMA center error: 1px
# step: 995,       EMA radius error: 1px.       EMA center error: 2px
# step: 996,       EMA radius error: 0px.       EMA center error: 3px
# step: 997,       EMA radius error: 1px.       EMA center error: 1px
# step: 998,       EMA radius error: 0px.       EMA center error: 4px
# step: 999,       EMA radius error: 11px.       EMA center error: 1px

# %% [markdown]
# Evaluate the model and perform inferrence

# %%
sample_batch, actual = DataGenerator(**params).generateOne()
prediction = model.predict(sample_batch,batch_size=BATCH_SIZE) # this seems to work ...

xp = prediction[0].reshape(-1,).astype(np.int32)
yp = prediction[1].reshape(-1,).astype(np.int32)
rp = prediction[2].reshape(-1,).astype(np.int32)
xa, ya, ra      = [np.rint(a).astype(np.int32) for a in actual]

result_display = []

# Add the prediction and the actual to the dataset
for i, sample in enumerate(sample_batch):
    draw_circle(sample, xa[i], ya[i], ra[i],  DARKNESS, CIRCLE_WIDTH)
    draw_circle(sample, xp[i], yp[i], rp[i], -DARKNESS, CIRCLE_WIDTH)  # The prediction will appear bright
    result_display.append(sample)

plot_dataset(np.array(result_display)[:,:,:,0])
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge44ade44db8f44aca60ee4da03c2cda7">
#     <br>
#     <input id="_anim_slidere44ade44db8f44aca60ee4da03c2cda7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime44ade44db8f44aca60ee4da03c2cda7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime44ade44db8f44aca60ee4da03c2cda7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte44ade44db8f44aca60ee4da03c2cda7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge44ade44db8f44aca60ee4da03c2cda7";
#     var slider_id = "_anim_slidere44ade44db8f44aca60ee4da03c2cda7";
#     var loop_select_id = "_anim_loop_selecte44ade44db8f44aca60ee4da03c2cda7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAIABJREFUeJzs3XuU7Wdd5/lvVe373nU/de45uRFI\
# SGQcVCCxA6YDtNB2G6dR8IijogwMI4IKSQZEerSbFgKRS4+CKNGRlUmczFrMWj0sE7FBVJIgDOM0\
# gVxIcs7JudWpe9W+X6rmD1ZX/WrvX76f5zlV4Ry636+/sp+n8tTev9v+nl/t/fkObWxsbBgAAACA\
# IMMX+gkAAAAA308ooAEAAIAIFNAAAABABApoAAAAIAIFNAAAABCBAhoAAACIQAENAAAARKCABgAA\
# ACJQQAMAAAARKKABAACACBTQAAAAQAQKaAAAACACBTQAAAAQgQIaAAAAiEABDQAAAESggAYAAAAi\
# UEADAAAAESigAQAAgAgU0AAAAEAECmgAAAAgAgU0AAAAEIECGgAAAIhAAQ0AAABEoIAGAAAAIlBA\
# AwAAABEooAEAAIAIFNAAAABABApoAAAAIAIFNAAAABCBAhoAAACIQAENAAAARKCABgAAACJQQAMA\
# AAARKKABAACACBTQAAAAQAQKaAAAACACBTQAAAAQgQIaAAAAiEABDQAAAESggAYAAAAiUEADAAAA\
# ESigAQAAgAgU0AAAAEAECmgAAAAgAgU0AAAAEIECGgAAAIhAAQ0AAABEoIAGAAAAIlBAAwAAABEo\
# oAEAAIAIFNAAAABABApoAAAAIAIFNAAAABCBAhoAAACIQAENAAAARKCABgAAACJQQAMAAAARKKAB\
# AACACBTQAAAAQAQKaAAAACACBTQAAAAQgQIaAAAAiEABDQAAAESggAYAAAAiUEADAAAAESigAQAA\
# gAgU0AAAAEAECmgAAAAgAgU0AAAAEIECGgAAAIhAAQ0AAABEoIAGAAAAIlBAAwAAABEooAEAAIAI\
# FNAAAABABApoAAAAIAIFNAAAABCBAhoAAACIQAENAAAARKCABgAAACJQQAMAAAARKKABAACACBTQ\
# AAAAQAQKaAAAACACBTQAAAAQIXOhnwDM/slf3brt8f92/W/Yf//gnZuPD1ZW5Brddf/fQrnhnlxj\
# eGjDna928nKNNfEzra4+5PKZrjufDXgta+3tz+OzN/y6vfErv7/5+NLRJbnGXLPizlfbObmGcvnY\
# ovyZ07XxHf+eptjuxWxHrrGvtLbt8Yf/m9+2d/3j72w+Xt8YkmuoY6zdG5FrFEb842OxVZJrjOWa\
# 7vxquyDXqHf8/b+3b3ulWWkXtz3+4x95t/3KP9yx+bjRyco1rpqYc+dP1ibkGuO5hr/Gml7j8Ojy\
# jtcYzbfc+XKmLddY6dt3d730XfZLD3948/G42PdmZiXxe87Ux+QaPXFNDjlfXjBxzp3vbOh7YNmh\
# dXe+0dPHWP816E9f9pv2iw99ZPPx4Yq/783MnlyZducPlFflGmsd/7w8XNbPY9j8a9CZht63nXX/\
# OhWyb4uZ7dfcP/ih2+1tX/+9zcc1cX0x08fydL4m17jrJXfJn0E6CujnyAc+8AH7x3/8RxsaGrL3\
# vOc99qIXvSj4/72isv85fGb/dbqSbbrrjpQOXein8F+cyysHLvRT+C8O19PdxzbdfZeVD17op4BI\
# FNDPga9+9at2/Phxu/fee+3JJ5+097znPXbvvfde6KcFAACAXcBnoJ8DDz74oL3yla80M7Mrr7zS\
# VlZWrFqtXuBnBQAAgN1AAf0cmJ+ft8nJyc3HU1NTNjfnf04RAAAA3x+GNjY2/E/UI9r73vc+e8Ur\
# XrF5F/pnf/Zn7QMf+IBdfvnlqT//VPUsnykDAAD4PsFnoJ8De/futfn5+c3H586ds5mZmWf9+WTi\
# hpnZ373qQ9uSOUjh2O58UjgefPUH7foHbtt8TArHdueTwvEX13/KfubBt2w+JoVju
